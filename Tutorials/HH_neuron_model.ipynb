# %%
from IPython.display import HTML, display

# %% [markdown]
# # <font color='green'>Hodgkin-Huxley Neuron Model </font>
#
# Hodgkin-Huxley model is the most 'complete' mathematical description of the action-potential generation in biological neurons. The model is complete in the sense that it provides mathematical equations that fit well with the voltage and time dependence of two most promiment currents involved in the generation of the action potential.
#
# ## <font color='green'>Aims of the tutorial </font>
# ### Simulate a Hodgkin-Huxley model
# ### Study the effect of change in the conductance of the Na and K channels
# ### Generate the input current and output firing rate curve
#
# ## <font color='green'>Learnign outcomes</font>
# ### An understanding of various components that affect the action potential e.g. threshold, shape and amplitude
#
# ## <font color='green'>What will you do</font>
# ### Execute the Python code and display the results and describe your observations
# ### Write small code snippetes to perform certain simulations in loop

# %% [markdown]
# ## <font color='green'>Equivalent electrical circuit</font>
# A neuron membrane can be described as an electrical circuit with batteris, voltage dependent resistors and a capacitor.
# <img src="./Figures/neuron_synapse_circuit_model.png">
#
# -  $C_m$ is the passive membrane capacitance
# -  $g_n$ are the active voltage-gated ion channels represented by electrical conductances (where 'n' is the specific ion channel) that depend on both voltage and time
# -  $g_L$ is the passive leak channel which accounrs for baseline flow of ions across the membrane and is represented by a linear conductance
# -  $E_n$ are the gradients driving the flow of ions (determined by intra- and extracellular concentrations and permeability of ions)
# - $g_{exc}$ is the excitatory synaptic conductance -- the so called 'conductance-based' synapse model
# - $g_{inh}$ is the inhibitory synaptic conductance -- the so called 'conductance-based' synapse model
# - $I_{exc}$ and $I_{inh}$ inhibotory synaptic currents -- when synapses are modelled as 'current-injections' as opposed to 'conductance changes'
#
#
# ## <font color='green'>The model</font>
#
# The differential equations governing the dynamics of voltage is given by:
#
# \begin{eqnarray*}
# C_m\frac{dV}{dt} & = & g_L(V-E_L) + \bar{g_{Na}}m^3h(V-E_{Na}) + \bar{g_K}n^4(V-E_K) + I_{inj} \\
# \frac{dm}{dt} & = & \alpha_m(1-m)-\beta_mm \\
# \frac{dh}{dt} & = & \alpha_h(1-h)-\beta_hh \\
# \frac{dn}{dt} & = & \alpha_n(1-n)-\beta_nn
# \end{eqnarray*}
#
# -  $I_{inj}$ is the injected current
# -  $\bar{g_n}$ are the maximum conductances for a given channel (sodium Na, potassium K, and leak L)
# -  $E_n$ are the reversal potentials for a given channel
# -  $n$, $m$, and $h$ are the gating variables
# -  $\alpha_x$ and $\beta_x$ are voltage dependent variable (see below)

# %% [markdown]
# ## <font color='green'>Voltage-dependent rate variables</font>
#
# $\alpha$ and $\beta$ are the voltage-dependent rates at which the activation and inactivation gates are opening or closing, respectively.
#
# \begin{eqnarray*}
# \alpha_m & = & \frac{-0.2 (V+25)}{exp\big(2.5 -\frac{V+50}{10}\big)-1} \\
# \beta_m & = & 4~exp\big(-\frac{V+50}{18}\big) \\
# \alpha_h & = & 0.07~exp\big(-\frac{V+40}{20}\big) \\
# \beta_h & = & \frac{1}{exp\big(3-\frac{V+40}{10}\big)+1} \\
# \alpha_n & = & -\frac{0.01 (V-10)}{exp\big(1 - \frac{V+20}{10}\big)-1} \\
# \beta_n & = & 0.0125~exp\big(-\frac{V+20}{80}\big) \\
# \end{eqnarray*}
#
# In the following cell we have python functions to calculate the values of $\alpha$ and $\beta$ variables and their steady state values of $m$, $h$, $n$

# %%
import numpy as np
import pylab as plt
import matplotlib as matplt
# %matplotlib inline
from scipy.integrate import odeint
np.random.seed(1000)

# %%
# Sodium ion-channel rate functions
def alpha_m(Vm):
    return (0.1 * (- Vm - 25.)) / (np.exp(2.5 - (0.1 * (Vm + 50.))) - 1.0)

def beta_m(Vm):
    return 4.0 * np.exp(-(Vm + 50.) / 18.0)

def alpha_h(Vm):
    return 0.07 * np.exp(-(Vm + 40.) / 20.0)

def beta_h(Vm):
    return 1.0 / (np.exp(3.0 - (0.1 * (Vm + 40.))) + 1.0)
  
# Pottasium ion-channel rate functions
def alpha_n(Vm):
    return (0.015 * (10.0 - Vm - 20.)) / (np.exp(1.0 - (0.1 * (Vm + 20.) )) - 1.0)

def beta_n(Vm):
    return 0.125 * np.exp(-(Vm + 20.) / 80.0)

# n, m, and h steady-state values

def n_inf(Vm=0.0):
    return alpha_n(Vm) / (alpha_n(Vm) + beta_n(Vm))

def m_inf(Vm=0.0):
    return alpha_m(Vm) / (alpha_m(Vm) + beta_m(Vm))

def h_inf(Vm=0.0):
    return alpha_h(Vm) / (alpha_h(Vm) + beta_h(Vm))

# %% [markdown]
# ## <font color='green'>Activation and inactivation curves of NA and K</font>

# %%
# Votage dependence of m, h, and n
voltage = np.arange(-80, 100, 0.1)
M = m_inf(voltage)
H = h_inf(voltage)
N = n_inf(voltage)

plt.figure(figsize=(10, 5))
plt.plot(voltage, M,linewidth=2, label=r'm')
plt.plot(voltage, H,linewidth=2, label=r'h')
plt.plot(voltage, N,linewidth=2, label=r'n')
plt.xlabel('Voltage (mV)')
plt.ylabel('Gating value')
plt.legend()
plt.show()

# %% [markdown]
# # <font color=blue>Describe</font>
# ### What do these shapes indicate?
#
# These curves indicate how the limit values of the different gating variables change with voltage. The limit is in terms of time approaching infinity.From these we can deduce steady-state conductance of the cell membrane to potassium and sodium respectively using the first differential equation.
#
# ### What can we predict about the shape, amplitude and threshold of an action potential?
#
# I don't think we can predict the shape of the action potential from these curves alone as they do not contain information about how these variables vary through time following a change in voltage. We can say that if the resting voltage of the cell is in the area where h = 0, the cell will only be conductive to potassium. Similarly, if the resting voltage of the cell is <-45, the membrane will be only permeable to potassium. From this we can see that our threshold potential is greater than ca. -45, as our neuron needs to become conductive to sodium in order to generate an action potential.

# %%
def compute_derivatives(y, t0):
    dy = np.zeros((4,))
    
    Vm = y[0]
    n = y[1]
    m = y[2]
    h = y[3]
    
    # dVm/dt
    GK = (gK / Cm) * np.power(n, 4.0)
    GNa = (gNa / Cm) * np.power(m, 3.0) * h
    GL = gL / Cm
    
    dy[0] = (I_inj(t0) / Cm) - (GK * (Vm - VK)) - (GNa * (Vm - VNa)) - (GL * (Vm - Vl))
    
    # dn/dt
    dy[1] = (alpha_n(Vm) * (1.0 - n)) - (beta_n(Vm) * n)
    
    # dm/dt
    dy[2] = (alpha_m(Vm) * (1.0 - m)) - (beta_m(Vm) * m)
    
    # dh/dt
    dy[3] = (alpha_h(Vm) * (1.0 - h)) - (beta_h(Vm) * h)
    
    return dy

# %%
# Start and end time (in milliseconds)
tmin = 0.0
tmax = 200.0

# Average potassium channel conductance per unit area (mS/cm^2)
gK = 80.0

# Average sodoum channel conductance per unit area (mS/cm^2)
gNa = 120.0

# Average leak channel conductance per unit area (mS/cm^2)
gL = 0.3

# Membrane capacitance per unit area (uF/cm^2)
Cm = 1.0

# Potassium potential (mV)
VK = -70.0

# Sodium potential (mV)
VNa = 50.0

# Leak potential (mV)
Vl = -65.

# Time values
T = np.linspace(tmin, tmax, 10000)

# Potassium ion-channel rate functions

# %%
# Input stimulus -- The following generates a Current Pulse 
# of amplitude 'stim_amp', which starts as 'stim_start' and ends at 'stim_end'
# Vary the input strength and stimulation durtion here
def I_inj(t, stim_amp = 7., stim_start = 30.0, stim_end = 130.):
    if 0.0 < t < stim_start:
        return 0.0
    elif stim_start < t < stim_end:
        return stim_amp
    elif stim_end < t < 191.0:
        return 0.0
    return 0.0

# %%
# State (Vm, n, m, h)
Y = np.array([-65.0, n_inf(), m_inf(), h_inf()])
# Solve ODE system
Vy = odeint(compute_derivatives, Y, T)

# Plot the results
plt.figure(figsize=(20, 15))
plt.subplot(311)
plt.plot(T,Vy[:,0],linewidth=2,label='voltage')
plt.legend()
plt.ylabel('Voltage [mV]')
plt.subplot(212)
plt.plot(T,Vy[:,2],linewidth=2,label='m')
plt.plot(T,Vy[:,3],linewidth=2,label='h')
plt.plot(T,Vy[:,1],linewidth=2,label='n')
plt.ylabel('Opening prob.')
plt.xlabel('Time [msec]')
plt.legend()

plt.show()

# %% [markdown]
# # <font color=blue>Describe</font>
# ### How do the opening and closing of the Na and K channels relate to the shape of the action potential
#
# In general, it seems that the combined opening of the two sodium gates cause the hyperpolarization phase of the action potential, until the membrane voltage reaches the sodium reversal potential, which seems to coincide with the rapid closing of the sodium-h gate. This is followed by the opening of the potassium gate, which causes the depolarization phase of the action potential, which lasts until the reversal potential of the potassium channel.
#
# ### Which channels are closed and opened in different phases of the action potential
#
# The action potentials rising phase seems to be directly preceded by a sharp increase in the permittivity of the m gate suggesting this rise is due to sodium, as before the action potential the two different types of sodium gates are both open. The end of the rising phase seems to correlate with the closing of the h gate, turning off the conductance of the sodium channels. The beginning of the depolarization phase of the action potential seems to be caused by the opening of the n gate, suggesting this phase is caused by the efflux of potassium ions.

# %% [markdown]
# ## Vary the Na conductance (gNa) and K conductance (gK) and study
# ### 1. how the number of action potentials generated varies as a function of gNa and gK
#
# First we can see that the number of action potentials is either 0 or 1 when gNa or gKa is 0, irrespective of what the complementary value is. In the case of gNa being zero, we never trigger an action potential, and in the case of gK being zero, we trigger exactly 1 action potential but are not able to "reset" for another action potential.
#
# When either gNa or gK is small, we see a significantly reduced number of action potentials.
#
# When both gNa and gK are sufficiently high, roughly 30 for both, further increases in either do not make a huge difference, and the number of action potentials seems to be relatively stable.
#
#
# ### 2. how the shape of the action potentials varies as a function of gNa and gK
#
# As we increase gK, we tend to see the general trend of discharge periods getting shorter. That is it takes less time for the action potential to reach resting voltage.
#
# The amplitude and slope during the rising phase of the action potential tends to be smaller when gNa is small. Also when gNa is small, the action potential does not seem to properly "reset".
#
# #### <font color=gray> Write a small code to count the number of action potentials. To this end you can write a small code to determine threshold cross from below. For this model you can set the spike threshold to -20mV. Alternatively, you can count the spikes manually. You can also write a small script to loop over different values of gNa and gK</font>

# %%
def count_action_potentials(Vy):
    ready_to_fire = True
    action_potentials = 0
    for i in range(Vy.shape[0]):
        voltage_rising = Vy[i][0] - Vy[i - 1][0] > 0
        if voltage_rising and ready_to_fire and Vy[i][0] > -20:
            action_potentials += 1
            ready_to_fire = False
        if not voltage_rising and not ready_to_fire and Vy[i][0] < -20:
            ready_to_fire = True
    return action_potentials

gKs = [0, 5, 10, 30, 60, 100]
gNas = [0, 5, 10, 30, 50, 100]
for gK in gKs:
    for gNa in gNas:
        Y = np.array([-65.0, n_inf(), m_inf(), h_inf()])
        # Solve ODE system
        Vy = odeint(compute_derivatives, Y, T)
        print(count_action_potentials(Vy), gK, gNa)    
        plt.figure(figsize=(20, 5))
        plt.plot(T,Vy[:,0],linewidth=5)
        plt.xlabel('Time [msec]')
        plt.ylabel('Voltage [mV]')
        plt.show()
# Out:
# 0 0 0
# 2 0 5
# 1 0 10
# 1 0 30
# 1 0 50
# 1 0 100
# 0 5 0
# 3 5 5
# 5 5 10
# 7 5 30
# 2 5 50
# 1 5 100
# 0 10 0
# 3 10 5
# 5 10 10
# 7 10 30
# 7 10 50
# 1 10 100
# 0 30 0
# 3 30 5
# 5 30 10
# 7 30 30
# 7 30 50
# 8 30 100
# 0 60 0
# 1 60 5
# 5 60 10
# 7 60 30
# 7 60 50
# 8 60 100
# 0 100 0
# 0 100 5
# 5 100 10
# 7 100 30
# 7 100 50
# 8 100 100

# %% [markdown]
# # <font color=green>Spike threshold</font>
# ## There are two ways to determine the spike threshold
# ### 1. Determine the minimum current necessary to generate an action potential. This is also referred to as Rheobase
# ### 2. We can also find the voltage at the double derivative of the action potential waveform is maximal as shown below

# %%
# Spike threshold at the point of maximum double derivative
def get_max_accelearation(vm):
    vm2 = np.diff(vm)
    #vm2 = np.diff(vm1)
    vm2 = (vm2-np.mean(vm2))/np.std(vm2)
    vm2[vm2<2.5]=0;
    xx = np.diff(vm2);
    xx[xx<0]=0;
    xx[xx>0]=1;
    dx = np.diff(xx)
    dx[dx<0]=0
    thr_ids = np.where(dx==1.)
    thr_cross = thr_ids[0]+3
    return thr_cross

# %%
gKs = np.linspace(0, 100, 20)
gNas = np.linspace(0, 100, 20)
xx, yy = np.meshgrid(gKs, gNas)
vals = np.concatenate((xx.reshape(-1, 1), yy.reshape(-1, 1)), axis=1)
Z = np.zeros(vals.shape[0])
for i, (gK, gNa) in enumerate(vals):
    Y = np.array([-65.0, n_inf(), m_inf(), h_inf()])
    # Solve ODE system
    Vy = odeint(compute_derivatives, Y, T)
    vm = Vy[:,0]
    spk_id = get_max_accelearation(vm)
    Z[i] = vm[spk_id].mean()
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.xlabel("gK")
plt.ylabel("gNa")
plt.colorbar()
plt.show()

plt.figure(figsize=(12, 5))
plt.plot(T,vm,linewidth=2,label='membrane potential')
plt.plot(T[spk_id],vm[spk_id],'o',ms = 10,linewidth=5,label='spike time')
plt.xlim((10,50))
plt.legend()
plt.show()

# %% [markdown]
# ### Vary the Na conductance (gNa) and K conductance (gK) and study spike threshold
#
# We can see that in general, spike threshold is not very affected by gK (there is not much variance in the contour plot along the x-axis), and that the spike threshold tends to increase as gNa increases.

# %% [markdown]
# # <font color=green>Input current and output spike count</font>
# ### Adapt the code below and study how input current amplitude determines the number of spikes

# %%
# Start and end time (in milliseconds)
tmin = 0.0
tmax = 200.0

# Average potassium channel conductance per unit area (mS/cm^2)
gK = 80.0

# Average sodoum channel conductance per unit area (mS/cm^2)
gNa = 120.0

# Average leak channel conductance per unit area (mS/cm^2)
gL = 0.3

# Membrane capacitance per unit area (uF/cm^2)
Cm = 1.0

# Potassium potential (mV)
VK = -70.0

# Sodium potential (mV)
VNa = 50.0

# Leak potential (mV)
Vl = -65.

# Time values
T = np.linspace(tmin, tmax, 10000)

# Potassium ion-channel rate functions

# %%
# Calculate the effect of injected current on the spike count
# Input stimulus
# Vary the input strength and stimulation durtion here
stimmys = np.linspace(0, 300, 10)
spike_counts = np.zeros(len(stimmys))
for i, stimmy in enumerate(stimmys):
    def I_inj(t, stim_amp = stimmy, stim_start = 30.0, stim_end = 150.):
        if 0.0 < t < stim_start:
            return 0.0
        elif stim_start < t < stim_end:
            return stim_amp
        elif stim_end < t < 200.0:
            return 0.0
        return 0.0

    Y = np.array([-65.0, n_inf(), m_inf(), h_inf()])
    # Solve ODE system
    Vy = odeint(compute_derivatives, Y, T)
    vm = Vy[:,0]
    spk_id = get_max_accelearation(vm)

    spike_counts[i] = len(spk_id)

    plt.figure(figsize=(12, 5))
    plt.clf()
    plt.plot(T,vm,linewidth=2,label='membrane potential')
    plt.plot(T[spk_id],vm[spk_id],'o',ms = 10,linewidth=5,label='spike time')
    #plt.xlim((2500,8000))
    plt.legend()
    plt.show()
    
    plt.figure(figsize=(12, 5))
    plt.clf()
    plt.plot(T,Vy[:, 1],linewidth=2,label='n gate')
    plt.plot(T,Vy[:, 3],linewidth=2,label='h gate')
    plt.plot(T,Vy[:, 2],linewidth=2,label='m gate')


    #plt.xlim((2500,8000))
    plt.legend()
    plt.show()
    
plt.figure(figsize=(12, 5))
plt.plot(stimmys, spike_counts, label="spike count vs current amplitude")
plt.legend()
plt.show()

# %% [markdown]
# ### Study the effect of injected current on the spike count
# #### <font color=gray>Write a loop around the above code and plot spike count as a function of injected current amplitude</font>
#
# We can see that the number of spikes increases with a high and constant slope until the current injected reaches roughly 50, whence the slope starts to level off a bit. Then when the current reaches around 100, the amount of spikes observed begins to decrease as current injected increases, at first sharply, and then the rate of decrease levels off.

# %% [markdown]
# ### In the above exercise you may have noticed that the number of spikes start to decrease at very high current amplitudes. Why does that happen?
# #### Investigate this by plotting the membrane voltage and corresponding K and Na openning/closing variables.
#
# If we increase the current amplitude past the point where the spikes begin to decrease, we can see that the membrane voltage begins to reach a point of stability around -15 mV. The higher the current the quicker we reach this point, and the fewer action potentials are produced.
#
# If we look at the gate variables we see that all 3 of them also reach stability at the same time as the membrane voltage. These voltages correspond to the rest state of the three channels at the corresponding stable membrane voltage.
#
# I believe that this is related to the "refractory period", after an action potential the cell needs to sufficiently depolarize in order for the sodium channel to be reset. The h-gate has an inverted relationship to voltage, meaning that we need the cell potential to reach a sufficiently low point after an action potential for the h-gate to become unblocked and allow for successive spikes. When the current injected is consistently

# %% [markdown]
# # <font color=salmon>TO DO</font>
# ### How can we estimate the effective time constant of the HH model? Think of a way and estimate the time constant
#
# The membrane time constant is known to be the time it takes for a charged capacitor to deplete to 36.8 percent of its initial charge, or the time for a capacitor to reach 63.2 percent of its charging voltage. Thus, one way of estimating this time constant is to take a neuron at rest and inject a constant current until the membrane potential reaches a new equilibrium state and measure how long it took for the membrane potential to reach 63.2 percent of this new equilibrium state.
#
# #### Describe what complications may arise in this way of estimation
#
# A possible problem with this estimation is that as the membrane potential increases so does the permittivity to sodium, lowering the resistance of the cell membrane. This would affect the results of our estimate as an assumption is that the resistance is kept constant.

# %%
injection_start = 30
def I_inj(t, stim_amp = 0.25, stim_start = injection_start, stim_end = 150.):
        if 0.0 < t < stim_start:
            return 0.0
        elif stim_start < t < stim_end:
            return stim_amp
        elif stim_end < t < 200.0:
            return 0.0
        return 0.0
    
Y = np.array([-65.0, n_inf(), m_inf(), h_inf()])
    # Solve ODE system
Vy = odeint(compute_derivatives, Y, T)
vm = Vy[:,0]
maximal_membrane_potential = np.amax(vm)
rest_potential = -65
value_looking_for = 0.632 * (maximal_membrane_potential - rest_potential)
idx = (np.abs(vm - value_looking_for)).argmin()
time = T[idx]
tau = time - injection_start
print(tau)
# Out:
# 69.74997499749975
